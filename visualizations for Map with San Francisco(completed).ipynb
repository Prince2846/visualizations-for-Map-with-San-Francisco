# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Interest = pd.read_csv("Topic_Survey_Assignment.csv")
Interest.head()
# Out:
#                             Very interested  Somewhat interested  \
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
#
#                             Not interested
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136

# %%
Interest_df = Interest.div(2233).mul(100)
Interest_df
# Out:
#                             Very interested  Somewhat interested  \
# Big Data (Spark / Hadoop)         59.650694            32.646664
# Data Analysis / Statistics        75.593372            19.883565
# Data Journalism                   19.211823            48.410210
# Data Visualization                60.008957            32.870578
# Deep Learning                     56.560681            34.482759
# Machine Learning                  72.951187            21.361397
#
#                             Not interested
# Big Data (Spark / Hadoop)         5.687416
# Data Analysis / Statistics        2.686968
# Data Journalism                  27.317510
# Data Visualization                4.567846
# Deep Learning                     6.090461
# Machine Learning                  3.313927

# %%
Interest_df2 = round(Interest_df, 2)
Interest_df2
# Out:
#                             Very interested  Somewhat interested  \
# Big Data (Spark / Hadoop)             59.65                32.65
# Data Analysis / Statistics            75.59                19.88
# Data Journalism                       19.21                48.41
# Data Visualization                    60.01                32.87
# Deep Learning                         56.56                34.48
# Machine Learning                      72.95                21.36
#
#                             Not interested
# Big Data (Spark / Hadoop)             5.69
# Data Analysis / Statistics            2.69
# Data Journalism                      27.32
# Data Visualization                    4.57
# Deep Learning                         6.09
# Machine Learning                      3.31

# %%
Interest_df3 = Interest_df2.astype(str) + '%'
Interest_df3
# Out:
#                            Very interested Somewhat interested Not interested
# Big Data (Spark / Hadoop)           59.65%              32.65%          5.69%
# Data Analysis / Statistics          75.59%              19.88%          2.69%
# Data Journalism                     19.21%              48.41%         27.32%
# Data Visualization                  60.01%              32.87%          4.57%
# Deep Learning                       56.56%              34.48%          6.09%
# Machine Learning                    72.95%              21.36%          3.31%

# %%
# Formatting to a percentage will be done in the plotting
#PLOTTING
ax1 = Interest_df2.plot(kind = 'bar',
                figsize = (20,8),
                width = 0.8,
                color = ('#5cb85c', '#5bc0de', '#d9534f'),
                fontsize = 14)
ax1.set_title("Percentage of Respondents' Interest in Data Science", 
             fontsize = 16)
ax1.legend(fontsize = 14)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)

# Adding the percentage values    
for p in ax1.patches:
    ax1.annotate("{:.2%}".format(p.get_height()),
    xy=(p.get_x()+0.02, p.get_height()+0.01))

# %%
# Formatting to a percentage will be done in the plotting
#PLOTTING
ax1 = Interest_df2.T.plot(kind = 'bar',
                figsize = (20,8),
                width = 0.8,
                color = ('#5cb85c', '#5bc0de', '#d9534f'),
                fontsize = 14)
ax1.set_title("Percentage of Respondents' Interest in Data Science", 
             fontsize = 16)
ax1.legend(fontsize = 14)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)

# Adding the percentage values    
for p in ax1.patches:
    ax1.annotate("{:.2%}".format(p.get_height()),
    xy=(p.get_x()+0.02, p.get_height()+0.01))

# %%
# just anoter exrcise of vizualisation using scatter
import matplotlib.pyplot as plt
   
Unemployment_Rate = [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2]
Stock_Index_Price = [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]
  
plt.scatter(Unemployment_Rate, Stock_Index_Price, color='green')
plt.title('Unemployment Rate Vs Stock Index Price', fontsize=14)
plt.xlabel('Unemployment Rate', fontsize=14)
plt.ylabel('Stock Index Price', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Visualization with Map

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
San_Francisco = pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016_.csv')

print('Dataset downloaded and read into a pandas dataframe!')
# Out:
# Dataset downloaded and read into a pandas dataframe!

# %%
San_Francisco.head(2)
# Out:
#    IncidntNum     Category                                        Descript  \
# 0   120058272  WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272  WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
#
#   DayOfWeek                    Date   Time PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
#
#                                Location            PdId
# 0  (37.775420706711, -122.403404791479)  12005827212120
# 1  (37.775420706711, -122.403404791479)  12005827212168

# %%
# let's seethe size of our dataset
San_Francisco.shape
# Out:
# (150500, 13)

# %%
# let's if they are any duplicate values in our column
San_Francisco['PdDistrict'].duplicated().sum()
# Out:
# 150489

# %%
# Let's drop duplicates values in our column
San_Francisco = San_Francisco.drop_duplicates(subset = ["PdDistrict"])

# %%
San_Francisco['PdDistrict'].duplicated().sum()
# Out:
# 0

# %%
# count the number of times each value appears in the a certain column
pd.value_counts(San_Francisco['PdDistrict'])
# Out:
# SOUTHERN      1
# BAYVIEW       1
# TENDERLOIN    1
# MISSION       1
# NORTHERN      1
# TARAVAL       1
# INGLESIDE     1
# CENTRAL       1
# RICHMOND      1
# PARK          1
# Name: PdDistrict, dtype: int64

# %%
San_Francisco['PdDistrict'].unique()
# Out:
# array(['SOUTHERN', 'BAYVIEW', 'TENDERLOIN', 'MISSION', 'NORTHERN',
#        'TARAVAL', 'INGLESIDE', 'CENTRAL', 'RICHMOND', 'PARK', nan],
#       dtype=object)

# %%
San_Francisco.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# PdId            int64
# dtype: object

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
world_map.save('Desktop')

# %%
# display world map# create a Stamen Terrain map of the world centered around San Fransisco

sf_zones = r'sf_neighborhoods.json'
#!pip install folium==0.5.0

sf_lat = 37.77
sf_lon = -122.42
fill_opacity=0.7
line_opacity=0.2
legend_name='San Fransisco'
tiles='Stamen Toner'

world_map = folium.Map(location=[sf_lat, sf_lon], 
                       zoom_start=12, 
                       tiles='Stamen Terrain',
                       
                       )
                                                                     

                       
# display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Mymap = folium.Map(location=[39.73912, -104.990337], zoom_start=4, width=500, height=300, control_scale=True)
Mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# create a Stamen Toner map of the world centered around Canada
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4, tiles='Stamen Toner')

# display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
